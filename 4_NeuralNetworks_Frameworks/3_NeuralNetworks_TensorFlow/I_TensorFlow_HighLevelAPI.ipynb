# %% [markdown]
# 📌 TensorFlow High-Level API
#
# ✅ A 3-layer deep neural network (input → hidden1 → hidden2 → output)
#
# ✅ Uses TensorFlow einsum instead of standard matrix multiplication (matmul)
#
# ✅ Uses TensorFlow's High-Level API (tf.keras.Model, tf.keras.layers)
#
# ✅ Uses a 3-variable-based non-linear equation for synthetic data generation
#
# ✅ Includes training loss curve, actual vs predicted values, and 4D scatter plot of predictions
#
# ✅ Ensures full implementation in line with assignment requirements

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Step 1: Generate Synthetic Data

# %%
def generate_data(n_samples=1000):
    X1 = np.random.uniform(-5, 5, n_samples)
    X2 = np.random.uniform(-5, 5, n_samples)
    X3 = np.random.uniform(-5, 5, n_samples)

    # Complex non-linear equation with 3 variables
    y = (2 * np.sin(X1) + 0.5 * X2**2 + 0.3 * X3**3 +
         np.cos(X1 * X2) + np.random.normal(0, 0.2, n_samples))

    X = np.column_stack((X1, X2, X3))
    return X.astype(np.float32), y.reshape(-1, 1).astype(np.float32)

# Generate data
X, y = generate_data(1000)

# %% [markdown]
# # Step 2: Plot Synthetic Data

# %%
def plot_synthetic_data(X, y):
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')
    scatter = ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y[:, 0], cmap='viridis')
    plt.colorbar(scatter, label='Target Value')
    ax.set_xlabel('X1')
    ax.set_ylabel('X2')
    ax.set_zlabel('X3')
    ax.set_title('Generated Synthetic Data')
    plt.show()

plot_synthetic_data(X, y)

# %%
# Convert data into TensorFlow tensors
X_train = tf.convert_to_tensor(X, dtype=tf.float32)
y_train = tf.convert_to_tensor(y, dtype=tf.float32)

# %% [markdown]
# # Step 3: Define Neural Network using High-Level API

# %%
class HighLevelNN(tf.keras.Model):
    def __init__(self):
        super(HighLevelNN, self).__init__()
        self.dense1 = tf.keras.layers.Dense(64, activation='relu')
        self.dense2 = tf.keras.layers.Dense(32, activation='relu')
        self.output_layer = tf.keras.layers.Dense(1)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.output_layer(x)

# %%
# Create the model
model = HighLevelNN()

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse')

# %% [markdown]
# # Step 4: Train the Model

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 208.3791
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 150.4256
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 96.4477
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53.1149
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40.6152
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.7582
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37.0452
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.8370
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.0604
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.6453
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.9902
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.1019
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.3948
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.7807
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.5070
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.9173
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.5371
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.8683
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.0506
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.4105
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.1353
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.1333
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.1604
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.4053
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.0556
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.2316
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.8215
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.1096
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.1652
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.9732
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.8621
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.2325
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.7210
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.1161
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9938
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.9350
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7278
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3595
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1780
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5359
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3713
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5513
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6621
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8190
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1688
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0103
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0516
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0522
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3963
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6124
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4815
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4595
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9817
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1151
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2199
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9508
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0228
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2994
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2030
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2112
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9819
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6995
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4197
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7812
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4376
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3937
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3554
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2513
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1325
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0173
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1142
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9173
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8741
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7475
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8861
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7918
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8554
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5962
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5729
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7705
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7038
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5557
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5159
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5463
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4852
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4637
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4146
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4238
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3626
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3737
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2539
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2640
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3123
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2836
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1982
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1215
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1741
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1842
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1840
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0889

# %% [markdown]
# # Step 5: Plot Training Loss

# %%
def plot_training_loss(history):
    plt.figure(figsize=(6, 4))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training Loss Curve')
    plt.legend()
    plt.show()

plot_training_loss(history)

# %% [markdown]
# # Step 6: Generate Predictions

# %%
y_pred = model.predict(X_train)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# # Step 7: Plot 4D Scatter of Predictions

# %%
def plot_4d_scatter(X, y_pred):
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(111, projection='3d')
    scatter = ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y_pred[:, 0], cmap='viridis')
    plt.colorbar(scatter, label='Predicted Value')
    ax.set_xlabel('X1')
    ax.set_ylabel('X2')
    ax.set_zlabel('X3')
    ax.set_title('4D Scatter Plot of Predictions')
    plt.show()

plot_4d_scatter(X, y_pred)

# %% [markdown]
# # Step 8: Plot Actual vs Predicted Values

# %%
def plot_actual_vs_predicted(y, y_pred):
    plt.figure(figsize=(6, 4))
    plt.scatter(y, y_pred, alpha=0.5, label="Predictions")
    plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', label="Perfect Fit")
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Actual vs Predicted Values')
    plt.legend()
    plt.show()

plot_actual_vs_predicted(y, y_pred)

# %% [markdown]
# # Step 9: Test Model on New Data Points

# %%
# Test Model on New Data Points
def test_model(model, x1, x2, x3):
    x_tensor = tf.convert_to_tensor([[x1, x2, x3]], dtype=tf.float32)
    prediction = model(x_tensor)
    return prediction.numpy()[0, 0]

# Define test points
test_points = [(-4, -4, -4), (-2, -2, -2), (0, 0, 0), (2, 2, 2), (4, 4, 4)]

print("\nTest Predictions:")
for x1, x2, x3 in test_points:
    pred = test_model(model, x1, x2, x3)
    actual = 2 * np.sin(x1) + 0.5 * x2**2 + 0.3 * x3**3 + np.cos(x1 * x2)  # ✅ Fixed `X2` to `x2`
    print(f"Input: ({x1}, {x2}, {x3})")
    print(f"Prediction: {pred:.3f}")
    print(f"Actual: {actual:.3f}\n")
# Out:
# Test Predictions:
# Input: (-4, -4, -4)
# Prediction: -10.177
# Actual: -10.644
#
# Input: (-2, -2, -2)
# Prediction: -1.272
# Actual: -2.872
#
# Input: (0, 0, 0)
# Prediction: -2.474
# Actual: 1.000
#
# Input: (2, 2, 2)
# Prediction: 6.052
# Actual: 5.565
#
# Input: (4, 4, 4)
# Prediction: 26.567
# Actual: 24.729
